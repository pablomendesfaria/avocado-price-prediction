# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.pipeline import Pipeline

from sklearn.dummy import DummyRegressor

from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import GridSearchCV

from yellowbrick.regressor import ResidualsPlot, PredictionError

# %% [markdown]
# ## Carregando os dadasets

# %%
X_train = pd.read_csv('../data/X_train.csv')
y_train = pd.read_csv('../data/y_train.csv').squeeze()

X_test = pd.read_csv('../data/X_test.csv')
y_test = pd.read_csv('../data/y_test.csv').squeeze()

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'-' * 27)
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (11591, 59)
# y_train shape: (11591,)
# ---------------------------
# X_test shape: (4968, 59)
# y_test shape: (4968,)

# %% [markdown]
# ## Construindo e Treinando o Módelo

# %% [markdown]
# Fazendo uma busca para encontrar o modelo com o melhor desempenho, tendo o criterio de pontuação o MSE.

# %%
pipeline = Pipeline([
    ('rgs', DummyRegressor())
])

grid_values = [
    {
        'rgs': [LinearRegression()]
    },
    {
        'rgs': [BaggingRegressor(base_estimator=RandomForestRegressor())],
    },
    {
        'rgs': [RandomForestRegressor()],
        'rgs__criterion': ['squared_error', 'absolute_error', 'poisson']
    },
    {
        'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor())],
        'rgs__loss': ['linear', 'square', 'exponential']
    },
    {
        'rgs': [GradientBoostingRegressor()],
        'rgs__loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'rgs__criterion': ['friedman_mse', 'squared_error']
    },
]

grid_search = GridSearchCV(pipeline, grid_values, scoring='neg_mean_squared_error', verbose=3)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ...........rgs=LinearRegression();, score=-0.072 total time=   0.1s
# [CV 2/5] END ...........rgs=LinearRegression();, score=-0.067 total time=   0.1s
# [CV 3/5] END ...........rgs=LinearRegression();, score=-0.068 total time=   0.1s
# [CV 4/5] END ...........rgs=LinearRegression();, score=-0.066 total time=   0.1s
# [CV 5/5] END ...........rgs=LinearRegression();, score=-0.069 total time=   0.1s
# [CV 1/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.022 total time=  39.9s
# [CV 2/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.021 total time= 1.1min
# [CV 3/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.023 total time= 1.4min
# [CV 4/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.021 total time=  57.6s
# [CV 5/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.022 total time=  43.8s
# [CV 1/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.020 total time=   8.3s
# [CV 2/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.019 total time=   6.2s
# [CV 3/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.020 total time=   6.2s
# [CV 4/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.018 total time=   6.2s
# [CV 5/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.018 total time=   6.2s
# [CV 1/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.019 total time= 4.5min
# [CV 2/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.019 total time= 4.6min
# [CV 3/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.020 total time= 4.8min
# [CV 4/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.019 total time= 5.0min
# [CV 5/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.020 total time= 4.8min
# [CV 1/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.019 total time=   8.0s
# [CV 2/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.019 total time=   7.9s
# [CV 3/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.020 total time=   8.8s
# [CV 4/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.018 total time=   8.0s
# [CV 5/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.019 total time=   8.3s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=linear;, score=-0.016 total time= 4.7min
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=linear;, score=-0.016 total time= 4.5min
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=linear;, score=-0.017 total time= 4.3min
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=linear;, score=-0.015 total time= 4.4min
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=linear;, score=-0.016 total time= 4.6min
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=square;, score=-0.017 total time= 4.3min
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=square;, score=-0.016 total time= 4.1min
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=square;, score=-0.017 total time= 4.2min
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=square;, score=-0.015 total time= 4.1min
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=square;, score=-0.016 total time= 4.2min
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=exponential;, score=-0.017 total time= 4.8min
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=exponential;, score=-0.016 total time= 4.6min
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=exponential;, score=-0.017 total time= 4.8min
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=exponential;, score=-0.015 total time= 4.7min
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor()), rgs__loss=exponential;, score=-0.016 total time= 4.8min
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.046 total time=   2.3s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.042 total time=   2.1s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.043 total time=   2.2s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.042 total time=   2.2s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.044 total time=   2.1s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.053 total time=   2.4s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.051 total time=   2.4s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.052 total time=   2.5s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.050 total time=   2.5s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.051 total time=   3.0s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.047 total time=   2.9s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.044 total time=   2.9s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.045 total time=   2.7s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.044 total time=   2.8s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.046 total time=   2.6s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.137 total time=   2.4s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.123 total time=   2.4s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.129 total time=   2.5s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.128 total time=   2.6s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.120 total time=   2.6s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.046 total time=   2.2s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.042 total time=   2.7s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.043 total time=   2.5s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.042 total time=   2.5s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.044 total time=   2.8s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.053 total time=   3.2s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.051 total time=   3.1s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.052 total time=   2.8s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.050 total time=   2.7s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.051 total time=   3.1s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.047 total time=   4.0s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.044 total time=   3.2s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.045 total time=   3.2s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.044 total time=   3.0s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.046 total time=   2.8s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.138 total time=   2.7s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.123 total time=   2.6s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.129 total time=   2.7s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.126 total time=   2.6s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.120 total time=   2.6s
# GridSearchCV(estimator=Pipeline(steps=[('rgs', DummyRegressor())]),
#              param_grid=[{'rgs': [LinearRegression()]},
#                          {'rgs': [BaggingRegressor(base_estimator=RandomForestRegressor())]},
#                          {'rgs': [RandomForestRegressor()],
#                           'rgs__criterion': ['squared_error', 'absolute_error',
#                                              'poisson']},
#                          {'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor())],
#                           'rgs__loss': ['linear', 'square', 'exponential']},
#                          {'rgs': [GradientBoostingRegressor()],
#                           'rgs__criterion': ['friedman_mse', 'squared_error'],
#                           'rgs__loss': ['squared_error', 'absolute_error',
#                                         'huber', 'quantile']}],
#              scoring='neg_mean_squared_error', verbose=3)

# %% [markdown]
# Visualizando qual foi o melhor modelo

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('rgs',
#                  AdaBoostRegressor(base_estimator=RandomForestRegressor()))])

# %% [markdown]
# A pontuação desse melhor modelo

# %%
grid_search.best_score_
# Out:
# -0.016079678054810004

# %% [markdown]
# Os parametros desse melhor modelo

# %%
grid_search.best_params_
# Out:
# {'rgs': AdaBoostRegressor(base_estimator=RandomForestRegressor()),
#  'rgs__loss': 'linear'}

# %%
model = grid_search.best_estimator_

# %% [markdown]
# ## Avaliação do Módelo

# %%
visualizer = ResidualsPlot(model)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# /home/enacom/.virtualenvs/py3cv4/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# <AxesSubplot: title={'center': 'Residuals for AdaBoostRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# Visualizando os residuais, podemos perceber que durante o treino o modelo obtev um escelente desempenho, com os valores residuais bem proximos de zero. Ja no teste temos uma dispersão um pouco maior, porem é uma dispersão equilibrada, tanto para cima quanto para baixo.

# %%
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# /home/enacom/.virtualenvs/py3cv4/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# <AxesSubplot: title={'center': 'Prediction Error for AdaBoostRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %% [markdown]
# Visualizando o erro, podemos perceber que a maioria dos valores estão proximos da linha diagonal, porem, percebe-se também que o modelo encontra mais dificuldade para predizer valores altos, de 2.5 pra cima começa a se perceber uma dispersão maior do erro.
