# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.pipeline import Pipeline

from sklearn.dummy import DummyRegressor

from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.model_selection import GridSearchCV

from yellowbrick.regressor import ResidualsPlot, PredictionError

# %% [markdown]
# ## Carregando os dadasets

# %%
X_train = pd.read_csv('../data/X_train.csv')
y_train = pd.read_csv('../data/y_train.csv').squeeze()

X_test = pd.read_csv('../data/X_test.csv')
y_test = pd.read_csv('../data/y_test.csv').squeeze()

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'-' * 27)
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (11591, 59)
# y_train shape: (11591,)
# ---------------------------
# X_test shape: (4968, 59)
# y_test shape: (4968,)

# %% [markdown]
# ## Construindo e Treinando o Módelo

# %% [markdown]
# Fazendo uma busca para encontrar o modelo com o melhor desempenho, tendo o criterio de pontuação o MSE.

# %%
pipeline = Pipeline([
    ('rgs', DummyRegressor())
])

grid_values = [
    {
        'rgs': [LinearRegression()]
    },
    {
        'rgs': [BaggingRegressor(base_estimator=RandomForestRegressor())],
    },
    {
        'rgs': [RandomForestRegressor()],
        'rgs__criterion': ['squared_error', 'absolute_error', 'poisson']
    },
    {
        'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1))],
        'rgs__loss': ['linear', 'square', 'exponential']
    },
    {
        'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2))],
        'rgs__loss': ['linear', 'square', 'exponential']
    },
    {
        'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3))],
        'rgs__loss': ['linear', 'square', 'exponential']
    },
    {
        'rgs': [GradientBoostingRegressor()],
        'rgs__loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'rgs__criterion': ['friedman_mse', 'squared_error']
    },
]

grid_search = GridSearchCV(pipeline, grid_values, scoring='neg_mean_squared_error', verbose=3)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 22 candidates, totalling 110 fits
# [CV 1/5] END ...........rgs=LinearRegression();, score=-0.072 total time=   0.1s
# [CV 2/5] END ...........rgs=LinearRegression();, score=-0.067 total time=   0.2s
# [CV 3/5] END ...........rgs=LinearRegression();, score=-0.068 total time=   0.1s
# [CV 4/5] END ...........rgs=LinearRegression();, score=-0.066 total time=   0.1s
# [CV 5/5] END ...........rgs=LinearRegression();, score=-0.069 total time=   0.1s
# [CV 1/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.022 total time=  39.1s
# [CV 2/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.021 total time=  38.9s
# [CV 3/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.023 total time=  39.2s
# [CV 4/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.021 total time=  39.5s
# [CV 5/5] END rgs=BaggingRegressor(base_estimator=RandomForestRegressor());, score=-0.022 total time=  40.2s
# [CV 1/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.019 total time=   6.4s
# [CV 2/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.019 total time=   6.4s
# [CV 3/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.020 total time=   6.2s
# [CV 4/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.018 total time=   6.3s
# [CV 5/5] END rgs=RandomForestRegressor(), rgs__criterion=squared_error;, score=-0.019 total time=   6.5s
# [CV 1/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.020 total time= 4.7min
# [CV 2/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.019 total time= 4.6min
# [CV 3/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.019 total time= 4.7min
# [CV 4/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.019 total time= 4.7min
# [CV 5/5] END rgs=RandomForestRegressor(), rgs__criterion=absolute_error;, score=-0.020 total time= 4.7min
# [CV 1/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.019 total time=   7.9s
# [CV 2/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.019 total time=   7.6s
# [CV 3/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.020 total time=   8.1s
# [CV 4/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.018 total time=   7.8s
# [CV 5/5] END rgs=RandomForestRegressor(), rgs__criterion=poisson;, score=-0.018 total time=   7.8s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=linear;, score=-0.018 total time=   3.2s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=linear;, score=-0.017 total time=   3.2s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=linear;, score=-0.018 total time=   3.1s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=linear;, score=-0.015 total time=   3.1s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=linear;, score=-0.017 total time=   3.2s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=square;, score=-0.019 total time=   3.0s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=square;, score=-0.017 total time=   2.8s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=square;, score=-0.017 total time=   3.0s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=square;, score=-0.015 total time=   3.0s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=square;, score=-0.016 total time=   3.0s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=exponential;, score=-0.018 total time=   3.3s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=exponential;, score=-0.017 total time=   3.2s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=exponential;, score=-0.018 total time=   3.2s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=exponential;, score=-0.017 total time=   3.2s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1)), rgs__loss=exponential;, score=-0.017 total time=   3.3s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=linear;, score=-0.018 total time=   5.9s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=linear;, score=-0.017 total time=   5.9s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=linear;, score=-0.018 total time=   5.9s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=linear;, score=-0.016 total time=   6.1s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=linear;, score=-0.016 total time=   5.9s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=square;, score=-0.017 total time=   5.5s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=square;, score=-0.016 total time=   5.6s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=square;, score=-0.017 total time=   5.3s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=square;, score=-0.015 total time=   5.5s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=square;, score=-0.016 total time=   5.7s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=exponential;, score=-0.018 total time=   6.1s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=exponential;, score=-0.017 total time=   6.9s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=exponential;, score=-0.018 total time=   6.0s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=exponential;, score=-0.016 total time=   6.1s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2)), rgs__loss=exponential;, score=-0.016 total time=   6.2s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=linear;, score=-0.018 total time=   8.9s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=linear;, score=-0.017 total time=   8.4s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=linear;, score=-0.018 total time=   8.5s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=linear;, score=-0.016 total time=   8.7s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=linear;, score=-0.016 total time=   8.6s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=square;, score=-0.017 total time=   8.1s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=square;, score=-0.016 total time=   7.9s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=square;, score=-0.016 total time=   8.0s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=square;, score=-0.015 total time=   7.8s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=square;, score=-0.016 total time=   7.7s
# [CV 1/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=exponential;, score=-0.018 total time=   8.6s
# [CV 2/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=exponential;, score=-0.017 total time=   8.8s
# [CV 3/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=exponential;, score=-0.018 total time=   8.6s
# [CV 4/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=exponential;, score=-0.016 total time=   9.0s
# [CV 5/5] END rgs=AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3)), rgs__loss=exponential;, score=-0.016 total time=   8.8s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.046 total time=   2.2s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.042 total time=   2.3s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.043 total time=   2.2s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.042 total time=   2.1s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=squared_error;, score=-0.044 total time=   2.2s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.054 total time=   2.4s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.051 total time=   2.5s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.052 total time=   2.4s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.051 total time=   2.5s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=absolute_error;, score=-0.051 total time=   2.5s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.047 total time=   2.6s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.044 total time=   2.6s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.045 total time=   2.6s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.044 total time=   2.6s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=huber;, score=-0.046 total time=   2.6s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.136 total time=   2.5s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.122 total time=   2.4s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.129 total time=   2.4s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.127 total time=   2.6s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=friedman_mse, rgs__loss=quantile;, score=-0.120 total time=   2.5s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.046 total time=   2.2s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.042 total time=   2.2s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.043 total time=   2.2s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.042 total time=   2.4s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=squared_error;, score=-0.044 total time=   2.2s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.053 total time=   2.5s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.051 total time=   2.5s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.053 total time=   2.5s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.051 total time=   2.4s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=absolute_error;, score=-0.051 total time=   2.4s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.047 total time=   2.7s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.044 total time=   2.6s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.045 total time=   2.6s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.044 total time=   2.6s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=huber;, score=-0.046 total time=   2.7s
# [CV 1/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.137 total time=   2.4s
# [CV 2/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.122 total time=   2.4s
# [CV 3/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.130 total time=   2.4s
# [CV 4/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.128 total time=   2.4s
# [CV 5/5] END rgs=GradientBoostingRegressor(), rgs__criterion=squared_error, rgs__loss=quantile;, score=-0.120 total time=   2.4s
# GridSearchCV(estimator=Pipeline(steps=[('rgs', DummyRegressor())]),
#              param_grid=[{'rgs': [LinearRegression()]},
#                          {'rgs': [BaggingRegressor(base_estimator=RandomForestRegressor())]},
#                          {'rgs': [RandomForestRegressor()],
#                           'rgs__criterion': ['squared_error', 'absolute_error',
#                                              'poisson']},
#                          {'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=1))]...
#                           'rgs__loss': ['linear', 'square', 'exponential']},
#                          {'rgs': [AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=3))],
#                           'rgs__loss': ['linear', 'square', 'exponential']},
#                          {'rgs': [GradientBoostingRegressor()],
#                           'rgs__criterion': ['friedman_mse', 'squared_error'],
#                           'rgs__loss': ['squared_error', 'absolute_error',
#                                         'huber', 'quantile']}],
#              scoring='neg_mean_squared_error', verbose=3)

# %% [markdown]
# Visualizando qual foi o melhor modelo

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('rgs',
#                  AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2),
#                                    loss='square'))])

# %% [markdown]
# A pontuação desse melhor modelo

# %%
grid_search.best_score_
# Out:
# -0.016300001376630978

# %% [markdown]
# Os parametros desse melhor modelo

# %%
grid_search.best_params_
# Out:
# {'rgs': AdaBoostRegressor(base_estimator=RandomForestRegressor(n_estimators=2),
#                    loss='square'),
#  'rgs__loss': 'square'}

# %%
model = grid_search.best_estimator_

# %% [markdown]
# ## Avaliação do Módelo

# %%
visualizer = ResidualsPlot(model)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# /home/enacom/.virtualenvs/py3cv4/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# <AxesSubplot: title={'center': 'Residuals for AdaBoostRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# Visualizando os residuais, podemos perceber que durante o treino o modelo obteve um excelente desempenho, com os valores residuais bem proximos de zero. Ja no teste temos uma dispersão um pouco maior, porem é uma dispersão equilibrada, tanto para cima quanto para baixo. Também da para notar que o modelo tem uma tendencia de predizer valores mais baixos no teste, o espaço a partir de 2.5 no valor previsto consta com poucas predições.

# %%
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# /home/enacom/.virtualenvs/py3cv4/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# <AxesSubplot: title={'center': 'Prediction Error for AdaBoostRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %% [markdown]
# Visualizando o erro, podemos perceber que a maioria dos valores estão proximos da linha diagonal, porem, percebe-se também que o modelo encontra mais dificuldade para predizer valores altos, de 2.5 pra cima começa a se perceber uma dispersão maior do erro.

# %%
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MAE: {mae}\nMSE: {mse}\nR2: {r2}')
# Out:
# MAE: 0.08902777777777778
# MSE: 0.015411865942028985
# R2: 0.9065317765076101

# %% [markdown]
# Olhando outras mais algumas métricas, vemos que o MAE esta com um erro bem baixo absoluto medio bem baixo, de apenas 0.09, porem precisamos lembrar que o valor a ser predizido também é baixo. O MSE se aproxima muito de zero, nos dizendo que o a maioria dos valores predizidos se aproximão dos valores reais. o R2 nos indica uma porcentagem de que o modelo foi capaz de explicar 90% da variancia dos dados de teste.
